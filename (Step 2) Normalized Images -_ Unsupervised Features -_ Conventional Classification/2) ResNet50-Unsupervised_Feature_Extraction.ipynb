# %%
from google.colab import drive
import os
DRIVE = '/gdrive'
WRK_DIR = DRIVE + '/MyDrive/Colab Notebooks/(Step 2) Normalized Images -> Unsupervised Features -> Conventional Classification'

drive.mount('/gdrive', force_remount=True)
os.chdir(WRK_DIR)
# Out:
# Mounted at /gdrive

# %%
'''
https://medium.com/@kenneth.ca95/a-guide-to-transfer-learning-with-keras-using-resnet50-a81a4a28084b
'''
from tensorflow.keras.applications.resnet50 import ResNet50, preprocess_input
from keras.preprocessing import image
import numpy as np
from tensorflow.keras.preprocessing.image import load_img
from tensorflow.keras.preprocessing.image import img_to_array
from keras.layers import Dense, Flatten
from keras.models import Model
# Load VGG16 model
resNet50_model = ResNet50(weights='imagenet', include_top=False, input_shape=(1536, 2048, 3))
# x = Flatten()(vgg_model.output)

x = Flatten()(resNet50_model.output)
# features = Dense(1000, activation='softmax')(x)
model = Model(inputs=resNet50_model.input, outputs=x)

# Define a function to extract features from an image
def extract_features(img_path):
    # Load the image
    img = load_img(img_path, target_size=(1536, 2048))
    # Convert the image to an array
    x = img_to_array(img)
    # Expand the dimensions of the array to match the input shape of the model
    x = np.expand_dims(x, axis=0)
    # Preprocess the input
    x = preprocess_input(x)
    # Extract features using the VGG16 model
    # features = vgg_model.predict(x)
    features = model.predict(x)
    # Flatten the features into a 1D array
    features = features.flatten()
    return features
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/resnet/resnet50_weights_tf_dim_ordering_tf_kernels_notop.h5
# 94765736/94765736 [==============================] - 4s 0us/step

# %%
import tensorflow as tf
tf.keras.backend.clear_session()

# %%
model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 1536, 2048,  0           []
#                                  3)]
#
#  conv1_pad (ZeroPadding2D)      (None, 1542, 2054,   0           ['input_1[0][0]']
#                                 3)
#
#  conv1_conv (Conv2D)            (None, 768, 1024, 6  9472        ['conv1_pad[0][0]']
#                                 4)
#
#  conv1_bn (BatchNormalization)  (None, 768, 1024, 6  256         ['conv1_conv[0][0]']
#                                 4)
#
#  conv1_relu (Activation)        (None, 768, 1024, 6  0           ['conv1_bn[0][0]']
#                                 4)
#
#  pool1_pad (ZeroPadding2D)      (None, 770, 1026, 6  0           ['conv1_relu[0][0]']
#                                 4)
#
#  pool1_pool (MaxPooling2D)      (None, 384, 512, 64  0           ['pool1_pad[0][0]']
#                                 )
#
#  conv2_block1_1_conv (Conv2D)   (None, 384, 512, 64  4160        ['pool1_pool[0][0]']
#                                 )
#
#  conv2_block1_1_bn (BatchNormal  (None, 384, 512, 64  256        ['conv2_block1_1_conv[0][0]']
#  ization)                       )
#
#  conv2_block1_1_relu (Activatio  (None, 384, 512, 64  0          ['conv2_block1_1_bn[0][0]']
#  n)                             )
#
#  conv2_block1_2_conv (Conv2D)   (None, 384, 512, 64  36928       ['conv2_block1_1_relu[0][0]']
#                                 )
#
#  conv2_block1_2_bn (BatchNormal  (None, 384, 512, 64  256        ['conv2_block1_2_conv[0][0]']
#  ization)                       )
#
#  conv2_block1_2_relu (Activatio  (None, 384, 512, 64  0          ['conv2_block1_2_bn[0][0]']
#  n)                             )
#
#  conv2_block1_0_conv (Conv2D)   (None, 384, 512, 25  16640       ['pool1_pool[0][0]']
#                                 6)
#
#  conv2_block1_3_conv (Conv2D)   (None, 384, 512, 25  16640       ['conv2_block1_2_relu[0][0]']
#                                 6)
#
#  conv2_block1_0_bn (BatchNormal  (None, 384, 512, 25  1024       ['conv2_block1_0_conv[0][0]']
#  ization)                       6)
#
#  conv2_block1_3_bn (BatchNormal  (None, 384, 512, 25  1024       ['conv2_block1_3_conv[0][0]']
#  ization)                       6)
#
#  conv2_block1_add (Add)         (None, 384, 512, 25  0           ['conv2_block1_0_bn[0][0]',
#                                 6)                                'conv2_block1_3_bn[0][0]']
#
#  conv2_block1_out (Activation)  (None, 384, 512, 25  0           ['conv2_block1_add[0][0]']
#                                 6)
#
#  conv2_block2_1_conv (Conv2D)   (None, 384, 512, 64  16448       ['conv2_block1_out[0][0]']
#                                 )
#
#  conv2_block2_1_bn (BatchNormal  (None, 384, 512, 64  256        ['conv2_block2_1_conv[0][0]']
#  ization)                       )
#
#  conv2_block2_1_relu (Activatio  (None, 384, 512, 64  0          ['conv2_block2_1_bn[0][0]']
#  n)                             )
#
#  conv2_block2_2_conv (Conv2D)   (None, 384, 512, 64  36928       ['conv2_block2_1_relu[0][0]']
#                                 )
#
#  conv2_block2_2_bn (BatchNormal  (None, 384, 512, 64  256        ['conv2_block2_2_conv[0][0]']
#  ization)                       )
#
#  conv2_block2_2_relu (Activatio  (None, 384, 512, 64  0          ['conv2_block2_2_bn[0][0]']
#  n)                             )
#
#  conv2_block2_3_conv (Conv2D)   (None, 384, 512, 25  16640       ['conv2_block2_2_relu[0][0]']
#                                 6)
#
#  conv2_block2_3_bn (BatchNormal  (None, 384, 512, 25  1024       ['conv2_block2_3_conv[0][0]']
#  ization)                       6)
#
#  conv2_block2_add (Add)         (None, 384, 512, 25  0           ['conv2_block1_out[0][0]',
#                                 6)                                'conv2_block2_3_bn[0][0]']
#
#  conv2_block2_out (Activation)  (None, 384, 512, 25  0           ['conv2_block2_add[0][0]']
#                                 6)
#
#  conv2_block3_1_conv (Conv2D)   (None, 384, 512, 64  16448       ['conv2_block2_out[0][0]']
#                                 )
#
#  conv2_block3_1_bn (BatchNormal  (None, 384, 512, 64  256        ['conv2_block3_1_conv[0][0]']
#  ization)                       )
#
#  conv2_block3_1_relu (Activatio  (None, 384, 512, 64  0          ['conv2_block3_1_bn[0][0]']
#  n)                             )
#
#  conv2_block3_2_conv (Conv2D)   (None, 384, 512, 64  36928       ['conv2_block3_1_relu[0][0]']
#                                 )
#
#  conv2_block3_2_bn (BatchNormal  (None, 384, 512, 64  256        ['conv2_block3_2_conv[0][0]']
#  ization)                       )
#
#  conv2_block3_2_relu (Activatio  (None, 384, 512, 64  0          ['conv2_block3_2_bn[0][0]']
#  n)                             )
#
#  conv2_block3_3_conv (Conv2D)   (None, 384, 512, 25  16640       ['conv2_block3_2_relu[0][0]']
#                                 6)
#
#  conv2_block3_3_bn (BatchNormal  (None, 384, 512, 25  1024       ['conv2_block3_3_conv[0][0]']
#  ization)                       6)
#
#  conv2_block3_add (Add)         (None, 384, 512, 25  0           ['conv2_block2_out[0][0]',
#                                 6)                                'conv2_block3_3_bn[0][0]']
#
#  conv2_block3_out (Activation)  (None, 384, 512, 25  0           ['conv2_block3_add[0][0]']
#                                 6)
#
#  conv3_block1_1_conv (Conv2D)   (None, 192, 256, 12  32896       ['conv2_block3_out[0][0]']
#                                 8)
#
#  conv3_block1_1_bn (BatchNormal  (None, 192, 256, 12  512        ['conv3_block1_1_conv[0][0]']
#  ization)                       8)
#
#  conv3_block1_1_relu (Activatio  (None, 192, 256, 12  0          ['conv3_block1_1_bn[0][0]']
#  n)                             8)
#
#  conv3_block1_2_conv (Conv2D)   (None, 192, 256, 12  147584      ['conv3_block1_1_relu[0][0]']
#                                 8)
#
#  conv3_block1_2_bn (BatchNormal  (None, 192, 256, 12  512        ['conv3_block1_2_conv[0][0]']
#  ization)                       8)
#
#  conv3_block1_2_relu (Activatio  (None, 192, 256, 12  0          ['conv3_block1_2_bn[0][0]']
#  n)                             8)
#
#  conv3_block1_0_conv (Conv2D)   (None, 192, 256, 51  131584      ['conv2_block3_out[0][0]']
#                                 2)
#
#  conv3_block1_3_conv (Conv2D)   (None, 192, 256, 51  66048       ['conv3_block1_2_relu[0][0]']
#                                 2)
#
#  conv3_block1_0_bn (BatchNormal  (None, 192, 256, 51  2048       ['conv3_block1_0_conv[0][0]']
#  ization)                       2)
#
#  conv3_block1_3_bn (BatchNormal  (None, 192, 256, 51  2048       ['conv3_block1_3_conv[0][0]']
#  ization)                       2)
#
#  conv3_block1_add (Add)         (None, 192, 256, 51  0           ['conv3_block1_0_bn[0][0]',
#                                 2)                                'conv3_block1_3_bn[0][0]']
#
#  conv3_block1_out (Activation)  (None, 192, 256, 51  0           ['conv3_block1_add[0][0]']
#                                 2)
#
#  conv3_block2_1_conv (Conv2D)   (None, 192, 256, 12  65664       ['conv3_block1_out[0][0]']
#                                 8)
#
#  conv3_block2_1_bn (BatchNormal  (None, 192, 256, 12  512        ['conv3_block2_1_conv[0][0]']
#  ization)                       8)
#
#  conv3_block2_1_relu (Activatio  (None, 192, 256, 12  0          ['conv3_block2_1_bn[0][0]']
#  n)                             8)
#
#  conv3_block2_2_conv (Conv2D)   (None, 192, 256, 12  147584      ['conv3_block2_1_relu[0][0]']
#                                 8)
#
#  conv3_block2_2_bn (BatchNormal  (None, 192, 256, 12  512        ['conv3_block2_2_conv[0][0]']
#  ization)                       8)
#
#  conv3_block2_2_relu (Activatio  (None, 192, 256, 12  0          ['conv3_block2_2_bn[0][0]']
#  n)                             8)
#
#  conv3_block2_3_conv (Conv2D)   (None, 192, 256, 51  66048       ['conv3_block2_2_relu[0][0]']
#                                 2)
#
#  conv3_block2_3_bn (BatchNormal  (None, 192, 256, 51  2048       ['conv3_block2_3_conv[0][0]']
#  ization)                       2)
#
#  conv3_block2_add (Add)         (None, 192, 256, 51  0           ['conv3_block1_out[0][0]',
#                                 2)                                'conv3_block2_3_bn[0][0]']
#
#  conv3_block2_out (Activation)  (None, 192, 256, 51  0           ['conv3_block2_add[0][0]']
#                                 2)
#
#  conv3_block3_1_conv (Conv2D)   (None, 192, 256, 12  65664       ['conv3_block2_out[0][0]']
#                                 8)
#
#  conv3_block3_1_bn (BatchNormal  (None, 192, 256, 12  512        ['conv3_block3_1_conv[0][0]']
#  ization)                       8)
#
#  conv3_block3_1_relu (Activatio  (None, 192, 256, 12  0          ['conv3_block3_1_bn[0][0]']
#  n)                             8)
#
#  conv3_block3_2_conv (Conv2D)   (None, 192, 256, 12  147584      ['conv3_block3_1_relu[0][0]']
#                                 8)
#
#  conv3_block3_2_bn (BatchNormal  (None, 192, 256, 12  512        ['conv3_block3_2_conv[0][0]']
#  ization)                       8)
#
#  conv3_block3_2_relu (Activatio  (None, 192, 256, 12  0          ['conv3_block3_2_bn[0][0]']
#  n)                             8)
#
#  conv3_block3_3_conv (Conv2D)   (None, 192, 256, 51  66048       ['conv3_block3_2_relu[0][0]']
#                                 2)
#
#  conv3_block3_3_bn (BatchNormal  (None, 192, 256, 51  2048       ['conv3_block3_3_conv[0][0]']
#  ization)                       2)
#
#  conv3_block3_add (Add)         (None, 192, 256, 51  0           ['conv3_block2_out[0][0]',
#                                 2)                                'conv3_block3_3_bn[0][0]']
#
#  conv3_block3_out (Activation)  (None, 192, 256, 51  0           ['conv3_block3_add[0][0]']
#                                 2)
#
#  conv3_block4_1_conv (Conv2D)   (None, 192, 256, 12  65664       ['conv3_block3_out[0][0]']
#                                 8)
#
#  conv3_block4_1_bn (BatchNormal  (None, 192, 256, 12  512        ['conv3_block4_1_conv[0][0]']
#  ization)                       8)
#
#  conv3_block4_1_relu (Activatio  (None, 192, 256, 12  0          ['conv3_block4_1_bn[0][0]']
#  n)                             8)
#
#  conv3_block4_2_conv (Conv2D)   (None, 192, 256, 12  147584      ['conv3_block4_1_relu[0][0]']
#                                 8)
#
#  conv3_block4_2_bn (BatchNormal  (None, 192, 256, 12  512        ['conv3_block4_2_conv[0][0]']
#  ization)                       8)
#
#  conv3_block4_2_relu (Activatio  (None, 192, 256, 12  0          ['conv3_block4_2_bn[0][0]']
#  n)                             8)
#
#  conv3_block4_3_conv (Conv2D)   (None, 192, 256, 51  66048       ['conv3_block4_2_relu[0][0]']
#                                 2)
#
#  conv3_block4_3_bn (BatchNormal  (None, 192, 256, 51  2048       ['conv3_block4_3_conv[0][0]']
#  ization)                       2)
#
#  conv3_block4_add (Add)         (None, 192, 256, 51  0           ['conv3_block3_out[0][0]',
#                                 2)                                'conv3_block4_3_bn[0][0]']
#
#  conv3_block4_out (Activation)  (None, 192, 256, 51  0           ['conv3_block4_add[0][0]']
#                                 2)
#
#  conv4_block1_1_conv (Conv2D)   (None, 96, 128, 256  131328      ['conv3_block4_out[0][0]']
#                                 )
#
#  conv4_block1_1_bn (BatchNormal  (None, 96, 128, 256  1024       ['conv4_block1_1_conv[0][0]']
#  ization)                       )
#
#  conv4_block1_1_relu (Activatio  (None, 96, 128, 256  0          ['conv4_block1_1_bn[0][0]']
#  n)                             )
#
#  conv4_block1_2_conv (Conv2D)   (None, 96, 128, 256  590080      ['conv4_block1_1_relu[0][0]']
#                                 )
#
#  conv4_block1_2_bn (BatchNormal  (None, 96, 128, 256  1024       ['conv4_block1_2_conv[0][0]']
#  ization)                       )
#
#  conv4_block1_2_relu (Activatio  (None, 96, 128, 256  0          ['conv4_block1_2_bn[0][0]']
#  n)                             )
#
#  conv4_block1_0_conv (Conv2D)   (None, 96, 128, 102  525312      ['conv3_block4_out[0][0]']
#                                 4)
#
#  conv4_block1_3_conv (Conv2D)   (None, 96, 128, 102  263168      ['conv4_block1_2_relu[0][0]']
#                                 4)
#
#  conv4_block1_0_bn (BatchNormal  (None, 96, 128, 102  4096       ['conv4_block1_0_conv[0][0]']
#  ization)                       4)
#
#  conv4_block1_3_bn (BatchNormal  (None, 96, 128, 102  4096       ['conv4_block1_3_conv[0][0]']
#  ization)                       4)
#
#  conv4_block1_add (Add)         (None, 96, 128, 102  0           ['conv4_block1_0_bn[0][0]',
#                                 4)                                'conv4_block1_3_bn[0][0]']
#
#  conv4_block1_out (Activation)  (None, 96, 128, 102  0           ['conv4_block1_add[0][0]']
#                                 4)
#
#  conv4_block2_1_conv (Conv2D)   (None, 96, 128, 256  262400      ['conv4_block1_out[0][0]']
#                                 )
#
#  conv4_block2_1_bn (BatchNormal  (None, 96, 128, 256  1024       ['conv4_block2_1_conv[0][0]']
#  ization)                       )
#
#  conv4_block2_1_relu (Activatio  (None, 96, 128, 256  0          ['conv4_block2_1_bn[0][0]']
#  n)                             )
#
#  conv4_block2_2_conv (Conv2D)   (None, 96, 128, 256  590080      ['conv4_block2_1_relu[0][0]']
#                                 )
#
#  conv4_block2_2_bn (BatchNormal  (None, 96, 128, 256  1024       ['conv4_block2_2_conv[0][0]']
#  ization)                       )
#
#  conv4_block2_2_relu (Activatio  (None, 96, 128, 256  0          ['conv4_block2_2_bn[0][0]']
#  n)                             )
#
#  conv4_block2_3_conv (Conv2D)   (None, 96, 128, 102  263168      ['conv4_block2_2_relu[0][0]']
#                                 4)
#
#  conv4_block2_3_bn (BatchNormal  (None, 96, 128, 102  4096       ['conv4_block2_3_conv[0][0]']
#  ization)                       4)
#
#  conv4_block2_add (Add)         (None, 96, 128, 102  0           ['conv4_block1_out[0][0]',
#                                 4)                                'conv4_block2_3_bn[0][0]']
#
#  conv4_block2_out (Activation)  (None, 96, 128, 102  0           ['conv4_block2_add[0][0]']
#                                 4)
#
#  conv4_block3_1_conv (Conv2D)   (None, 96, 128, 256  262400      ['conv4_block2_out[0][0]']
#                                 )
#
#  conv4_block3_1_bn (BatchNormal  (None, 96, 128, 256  1024       ['conv4_block3_1_conv[0][0]']
#  ization)                       )
#
#  conv4_block3_1_relu (Activatio  (None, 96, 128, 256  0          ['conv4_block3_1_bn[0][0]']
#  n)                             )
#
#  conv4_block3_2_conv (Conv2D)   (None, 96, 128, 256  590080      ['conv4_block3_1_relu[0][0]']
#                                 )
#
#  conv4_block3_2_bn (BatchNormal  (None, 96, 128, 256  1024       ['conv4_block3_2_conv[0][0]']
#  ization)                       )
#
#  conv4_block3_2_relu (Activatio  (None, 96, 128, 256  0          ['conv4_block3_2_bn[0][0]']
#  n)                             )
#
#  conv4_block3_3_conv (Conv2D)   (None, 96, 128, 102  263168      ['conv4_block3_2_relu[0][0]']
#                                 4)
#
#  conv4_block3_3_bn (BatchNormal  (None, 96, 128, 102  4096       ['conv4_block3_3_conv[0][0]']
#  ization)                       4)
#
#  conv4_block3_add (Add)         (None, 96, 128, 102  0           ['conv4_block2_out[0][0]',
#                                 4)                                'conv4_block3_3_bn[0][0]']
#
#  conv4_block3_out (Activation)  (None, 96, 128, 102  0           ['conv4_block3_add[0][0]']
#                                 4)
#
#  conv4_block4_1_conv (Conv2D)   (None, 96, 128, 256  262400      ['conv4_block3_out[0][0]']
#                                 )
#
#  conv4_block4_1_bn (BatchNormal  (None, 96, 128, 256  1024       ['conv4_block4_1_conv[0][0]']
#  ization)                       )
#
#  conv4_block4_1_relu (Activatio  (None, 96, 128, 256  0          ['conv4_block4_1_bn[0][0]']
#  n)                             )
#
#  conv4_block4_2_conv (Conv2D)   (None, 96, 128, 256  590080      ['conv4_block4_1_relu[0][0]']
#                                 )
#
#  conv4_block4_2_bn (BatchNormal  (None, 96, 128, 256  1024       ['conv4_block4_2_conv[0][0]']
#  ization)                       )
#
#  conv4_block4_2_relu (Activatio  (None, 96, 128, 256  0          ['conv4_block4_2_bn[0][0]']
#  n)                             )
#
#  conv4_block4_3_conv (Conv2D)   (None, 96, 128, 102  263168      ['conv4_block4_2_relu[0][0]']
#                                 4)
#
#  conv4_block4_3_bn (BatchNormal  (None, 96, 128, 102  4096       ['conv4_block4_3_conv[0][0]']
#  ization)                       4)
#
#  conv4_block4_add (Add)         (None, 96, 128, 102  0           ['conv4_block3_out[0][0]',
#                                 4)                                'conv4_block4_3_bn[0][0]']
#
#  conv4_block4_out (Activation)  (None, 96, 128, 102  0           ['conv4_block4_add[0][0]']
#                                 4)
#
#  conv4_block5_1_conv (Conv2D)   (None, 96, 128, 256  262400      ['conv4_block4_out[0][0]']
#                                 )
#
#  conv4_block5_1_bn (BatchNormal  (None, 96, 128, 256  1024       ['conv4_block5_1_conv[0][0]']
#  ization)                       )
#
#  conv4_block5_1_relu (Activatio  (None, 96, 128, 256  0          ['conv4_block5_1_bn[0][0]']
#  n)                             )
#
#  conv4_block5_2_conv (Conv2D)   (None, 96, 128, 256  590080      ['conv4_block5_1_relu[0][0]']
#                                 )
#
#  conv4_block5_2_bn (BatchNormal  (None, 96, 128, 256  1024       ['conv4_block5_2_conv[0][0]']
#  ization)                       )
#
#  conv4_block5_2_relu (Activatio  (None, 96, 128, 256  0          ['conv4_block5_2_bn[0][0]']
#  n)                             )
#
#  conv4_block5_3_conv (Conv2D)   (None, 96, 128, 102  263168      ['conv4_block5_2_relu[0][0]']
#                                 4)
#
#  conv4_block5_3_bn (BatchNormal  (None, 96, 128, 102  4096       ['conv4_block5_3_conv[0][0]']
#  ization)                       4)
#
#  conv4_block5_add (Add)         (None, 96, 128, 102  0           ['conv4_block4_out[0][0]',
#                                 4)                                'conv4_block5_3_bn[0][0]']
#
#  conv4_block5_out (Activation)  (None, 96, 128, 102  0           ['conv4_block5_add[0][0]']
#                                 4)
#
#  conv4_block6_1_conv (Conv2D)   (None, 96, 128, 256  262400      ['conv4_block5_out[0][0]']
#                                 )
#
#  conv4_block6_1_bn (BatchNormal  (None, 96, 128, 256  1024       ['conv4_block6_1_conv[0][0]']
#  ization)                       )
#
#  conv4_block6_1_relu (Activatio  (None, 96, 128, 256  0          ['conv4_block6_1_bn[0][0]']
#  n)                             )
#
#  conv4_block6_2_conv (Conv2D)   (None, 96, 128, 256  590080      ['conv4_block6_1_relu[0][0]']
#                                 )
#
#  conv4_block6_2_bn (BatchNormal  (None, 96, 128, 256  1024       ['conv4_block6_2_conv[0][0]']
#  ization)                       )
#
#  conv4_block6_2_relu (Activatio  (None, 96, 128, 256  0          ['conv4_block6_2_bn[0][0]']
#  n)                             )
#
#  conv4_block6_3_conv (Conv2D)   (None, 96, 128, 102  263168      ['conv4_block6_2_relu[0][0]']
#                                 4)
#
#  conv4_block6_3_bn (BatchNormal  (None, 96, 128, 102  4096       ['conv4_block6_3_conv[0][0]']
#  ization)                       4)
#
#  conv4_block6_add (Add)         (None, 96, 128, 102  0           ['conv4_block5_out[0][0]',
#                                 4)                                'conv4_block6_3_bn[0][0]']
#
#  conv4_block6_out (Activation)  (None, 96, 128, 102  0           ['conv4_block6_add[0][0]']
#                                 4)
#
#  conv5_block1_1_conv (Conv2D)   (None, 48, 64, 512)  524800      ['conv4_block6_out[0][0]']
#
#  conv5_block1_1_bn (BatchNormal  (None, 48, 64, 512)  2048       ['conv5_block1_1_conv[0][0]']
#  ization)
#
#  conv5_block1_1_relu (Activatio  (None, 48, 64, 512)  0          ['conv5_block1_1_bn[0][0]']
#  n)
#
#  conv5_block1_2_conv (Conv2D)   (None, 48, 64, 512)  2359808     ['conv5_block1_1_relu[0][0]']
#
#  conv5_block1_2_bn (BatchNormal  (None, 48, 64, 512)  2048       ['conv5_block1_2_conv[0][0]']
#  ization)
#
#  conv5_block1_2_relu (Activatio  (None, 48, 64, 512)  0          ['conv5_block1_2_bn[0][0]']
#  n)
#
#  conv5_block1_0_conv (Conv2D)   (None, 48, 64, 2048  2099200     ['conv4_block6_out[0][0]']
#                                 )
#
#  conv5_block1_3_conv (Conv2D)   (None, 48, 64, 2048  1050624     ['conv5_block1_2_relu[0][0]']
#                                 )
#
#  conv5_block1_0_bn (BatchNormal  (None, 48, 64, 2048  8192       ['conv5_block1_0_conv[0][0]']
#  ization)                       )
#
#  conv5_block1_3_bn (BatchNormal  (None, 48, 64, 2048  8192       ['conv5_block1_3_conv[0][0]']
#  ization)                       )
#
#  conv5_block1_add (Add)         (None, 48, 64, 2048  0           ['conv5_block1_0_bn[0][0]',
#                                 )                                 'conv5_block1_3_bn[0][0]']
#
#  conv5_block1_out (Activation)  (None, 48, 64, 2048  0           ['conv5_block1_add[0][0]']
#                                 )
#
#  conv5_block2_1_conv (Conv2D)   (None, 48, 64, 512)  1049088     ['conv5_block1_out[0][0]']
#
#  conv5_block2_1_bn (BatchNormal  (None, 48, 64, 512)  2048       ['conv5_block2_1_conv[0][0]']
#  ization)
#
#  conv5_block2_1_relu (Activatio  (None, 48, 64, 512)  0          ['conv5_block2_1_bn[0][0]']
#  n)
#
#  conv5_block2_2_conv (Conv2D)   (None, 48, 64, 512)  2359808     ['conv5_block2_1_relu[0][0]']
#
#  conv5_block2_2_bn (BatchNormal  (None, 48, 64, 512)  2048       ['conv5_block2_2_conv[0][0]']
#  ization)
#
#  conv5_block2_2_relu (Activatio  (None, 48, 64, 512)  0          ['conv5_block2_2_bn[0][0]']
#  n)
#
#  conv5_block2_3_conv (Conv2D)   (None, 48, 64, 2048  1050624     ['conv5_block2_2_relu[0][0]']
#                                 )
#
#  conv5_block2_3_bn (BatchNormal  (None, 48, 64, 2048  8192       ['conv5_block2_3_conv[0][0]']
#  ization)                       )
#
#  conv5_block2_add (Add)         (None, 48, 64, 2048  0           ['conv5_block1_out[0][0]',
#                                 )                                 'conv5_block2_3_bn[0][0]']
#
#  conv5_block2_out (Activation)  (None, 48, 64, 2048  0           ['conv5_block2_add[0][0]']
#                                 )
#
#  conv5_block3_1_conv (Conv2D)   (None, 48, 64, 512)  1049088     ['conv5_block2_out[0][0]']
#
#  conv5_block3_1_bn (BatchNormal  (None, 48, 64, 512)  2048       ['conv5_block3_1_conv[0][0]']
#  ization)
#
#  conv5_block3_1_relu (Activatio  (None, 48, 64, 512)  0          ['conv5_block3_1_bn[0][0]']
#  n)
#
#  conv5_block3_2_conv (Conv2D)   (None, 48, 64, 512)  2359808     ['conv5_block3_1_relu[0][0]']
#
#  conv5_block3_2_bn (BatchNormal  (None, 48, 64, 512)  2048       ['conv5_block3_2_conv[0][0]']
#  ization)
#
#  conv5_block3_2_relu (Activatio  (None, 48, 64, 512)  0          ['conv5_block3_2_bn[0][0]']
#  n)
#
#  conv5_block3_3_conv (Conv2D)   (None, 48, 64, 2048  1050624     ['conv5_block3_2_relu[0][0]']
#                                 )
#
#  conv5_block3_3_bn (BatchNormal  (None, 48, 64, 2048  8192       ['conv5_block3_3_conv[0][0]']
#  ization)                       )
#
#  conv5_block3_add (Add)         (None, 48, 64, 2048  0           ['conv5_block2_out[0][0]',
#                                 )                                 'conv5_block3_3_bn[0][0]']
#
#  conv5_block3_out (Activation)  (None, 48, 64, 2048  0           ['conv5_block3_add[0][0]']
#                                 )
#
#  flatten (Flatten)              (None, 6291456)      0           ['conv5_block3_out[0][0]']
#
# ==================================================================================================
# Total params: 23,587,712
# Trainable params: 23,534,592
# Non-trainable params: 53,120
# __________________________________________________________________________________________________

# %%
import os
import csv
import numpy as np
from tensorflow.keras.applications.resnet50 import ResNet50, preprocess_input
from keras.preprocessing import image

# Define the paths to the image files
dest_path = '/gdrive/My Drive/Normalized_Images/'
categories = ['Benign', 'Normal', 'Invasive', 'InSitu']

# Create an empty dictionary to store the extracted features
features_dict = {}

# Loop through each category and extract the features for each image
for category in categories:
    src_path = dest_path + category + '/'
    files = os.listdir(src_path)
    i = 0
    for file in files:
        if file.endswith('.tif'):
            img_path = src_path + file
            features = extract_features(img_path)
            features_dict[file] = features
            print(i)
            i+=1

# Write the features to a CSV file
# with open('/gdrive/My Drive/image_features.csv', 'w', newline='') as csvfile:
#     writer = csv.writer(csvfile)
#     writer.writerow(['filename'] + ['feature{}'.format(i) for i in range(7*7*512)])
#     for file, features in features_dict.items():
#         writer.writerow([file] + list(features))
# Out:
# 1/1 [==============================] - 11s 11s/step
# 0
# 1/1 [==============================] - 0s 219ms/step
# 1
# 1/1 [==============================] - 0s 74ms/step
# 2
# 1/1 [==============================] - 0s 60ms/step
# 3
# 1/1 [==============================] - 0s 79ms/step
# 4
# 1/1 [==============================] - 0s 88ms/step
# 5
# 1/1 [==============================] - 0s 60ms/step
# 6
# 1/1 [==============================] - 0s 60ms/step
# 7
# 1/1 [==============================] - 0s 65ms/step
# 8
# 1/1 [==============================] - 0s 64ms/step
# 9
# 1/1 [==============================] - 0s 61ms/step
# 10
# 1/1 [==============================] - 0s 61ms/step
# 11
# 1/1 [==============================] - 0s 62ms/step
# 12
# 1/1 [==============================] - 0s 60ms/step
# 13
# 1/1 [==============================] - 0s 60ms/step
# 14
# 1/1 [==============================] - 0s 60ms/step
# 15
# 1/1 [==============================] - 0s 63ms/step
# 16
# 1/1 [==============================] - 0s 61ms/step
# 17
# 1/1 [==============================] - 0s 61ms/step
# 18
# 1/1 [==============================] - 0s 61ms/step
# 19
# 1/1 [==============================] - 0s 62ms/step
# 20
# 1/1 [==============================] - 0s 61ms/step
# 21
# 1/1 [==============================] - 0s 62ms/step
# 22
# 1/1 [==============================] - 0s 60ms/step
# 23
# 1/1 [==============================] - 0s 62ms/step
# 24
# 1/1 [==============================] - 0s 63ms/step
# 25
# 1/1 [==============================] - 0s 61ms/step
# 26
# 1/1 [==============================] - 0s 63ms/step
# 27
# 1/1 [==============================] - 0s 61ms/step
# 28
# 1/1 [==============================] - 0s 60ms/step
# 29
# 1/1 [==============================] - 0s 61ms/step
# 30
# 1/1 [==============================] - 0s 61ms/step
# 31
# 1/1 [==============================] - 0s 60ms/step
# 32
# 1/1 [==============================] - 0s 60ms/step
# 33
# 1/1 [==============================] - 0s 60ms/step
# 34
# 1/1 [==============================] - 0s 59ms/step
# 35
# 1/1 [==============================] - 0s 60ms/step
# 36
# 1/1 [==============================] - 0s 61ms/step
# 37
# 1/1 [==============================] - 0s 62ms/step
# 38
# 1/1 [==============================] - 0s 60ms/step
# 39
# 1/1 [==============================] - 0s 60ms/step
# 40
# 1/1 [==============================] - 0s 64ms/step
# 41
# 1/1 [==============================] - 0s 62ms/step
# 42
# 1/1 [==============================] - 0s 62ms/step
# 43
# 1/1 [==============================] - 0s 62ms/step
# 44
# 1/1 [==============================] - 0s 68ms/step
# 45
# 1/1 [==============================] - 0s 62ms/step
# 46
# 1/1 [==============================] - 0s 62ms/step
# 47
# 1/1 [==============================] - 0s 61ms/step
# 48
# 1/1 [==============================] - 0s 60ms/step
# 49
# 1/1 [==============================] - 0s 61ms/step
# 50
# 1/1 [==============================] - 0s 60ms/step
# 51
# 1/1 [==============================] - 0s 60ms/step
# 52
# 1/1 [==============================] - 0s 58ms/step
# 53
# 1/1 [==============================] - 0s 63ms/step
# 54
# 1/1 [==============================] - 0s 60ms/step
# 50
# 1/1 [==============================] - 0s 63ms/step
# 51
# 1/1 [==============================] - 0s 62ms/step
# 52
# 1/1 [==============================] - 0s 62ms/step
# 53
# 1/1 [==============================] - 0s 62ms/step
# 54
# 1/1 [==============================] - 0s 61ms/step
# 55
# 1/1 [==============================] - 0s 60ms/step
# 56
# 1/1 [==============================] - 0s 60ms/step
# 57
# 1/1 [==============================] - 0s 61ms/step
# 58
# 1/1 [==============================] - 0s 62ms/step
# 59
# 1/1 [==============================] - 0s 63ms/step
# 60
# 1/1 [==============================] - 0s 61ms/step
# 61
# 1/1 [==============================] - 0s 62ms/step
# 62
# 1/1 [==============================] - 0s 62ms/step
# 63
# 1/1 [==============================] - 0s 61ms/step
# 64
# 1/1 [==============================] - 0s 62ms/step
# 65
# 1/1 [==============================] - 0s 60ms/step
# 66
# 1/1 [==============================] - 0s 60ms/step
# 67
# 1/1 [==============================] - 0s 62ms/step
# 68
# 1/1 [==============================] - 0s 63ms/step
# 69
# 1/1 [==============================] - 0s 65ms/step
# 70
# 1/1 [==============================] - 0s 64ms/step
# 71
# 1/1 [==============================] - 0s 64ms/step
# 72
# 1/1 [==============================] - 0s 63ms/step
# 73
# 1/1 [==============================] - 0s 59ms/step
# 74
# 1/1 [==============================] - 0s 61ms/step
# 75
# 1/1 [==============================] - 0s 60ms/step
# 76
# 1/1 [==============================] - 0s 62ms/step
# 77
# 1/1 [==============================] - 0s 62ms/step
# 78
# 1/1 [==============================] - 0s 59ms/step
# 79
# 1/1 [==============================] - 0s 66ms/step
# 80
# 1/1 [==============================] - 0s 60ms/step
# 81
# 1/1 [==============================] - 0s 63ms/step
# 82
# 1/1 [==============================] - 0s 62ms/step
# 83
# 1/1 [==============================] - 0s 63ms/step
# 84
# 1/1 [==============================] - 0s 62ms/step
# 85
# 1/1 [==============================] - 0s 61ms/step
# 86
# 1/1 [==============================] - 0s 61ms/step
# 87
# 1/1 [==============================] - 0s 61ms/step
# 88
# 1/1 [==============================] - 0s 61ms/step
# 89
# 1/1 [==============================] - 0s 61ms/step
# 90
# 1/1 [==============================] - 0s 65ms/step
# 91
# 1/1 [==============================] - 0s 61ms/step
# 92
# 1/1 [==============================] - 0s 62ms/step
# 93
# 1/1 [==============================] - 0s 63ms/step
# 94
# 1/1 [==============================] - 0s 61ms/step
# 95
# 1/1 [==============================] - 0s 59ms/step
# 96
# 1/1 [==============================] - 0s 60ms/step
# 97
# 1/1 [==============================] - 0s 60ms/step
# 98
# 1/1 [==============================] - 0s 61ms/step
# 99

# %%
features.shape
# Out:
# (6291456,)

# %%
# Write the features to a CSV file
# with open('/gdrive/My Drive/image_features.csv', 'w', newline='') as csvfile:
#     writer = csv.writer(csvfile)
#     writer.writerow(['filename'] + ['feature{}'.format(i) for i in range(6291456)])
#     for file, features in features_dict.items():
#         writer.writerow([file] + list(features))

# %%
my_array = np.array(list(features_dict.values()))

# %%
print(my_array.shape)
# Out:
# (400, 6291456)

# %%
np.save('ResNet50_Extracted_Features.npy', my_array)
